# %% [markdown]
# # 網路爬蟲基礎

# %% [markdown]
# 參考網站 : https://blog.jiatool.com/posts/gamer_ani_spider/
#
# 巴哈姆特 動畫瘋：新手入門基礎網路爬蟲教學，
# 爬取"巴哈姆特 動畫瘋"的本季新番動畫資訊

# %%
import os
import requests
from bs4 import BeautifulSoup

# %%
# 巴哈姆特動畫瘋 網址
url = 'https://ani.gamer.com.tw/'

# %% [markdown]
# ## 1. 發出請求

# %%
import requests

r = requests.get(url)
if r.status_code == 200:  # 200 : 請求已成功，請求所希望的回應頭或資料體將隨此回應返回。
    print(f'請求成功：{r.status_code}')
else:
    print(f'請求失敗：{r.status_code}')
# Out:
# 請求失敗：403

# %% [markdown]
# Note (http 狀態碼):  https://zh.wikipedia.org/wiki/HTTP%E7%8A%B6%E6%80%81%E7%A0%81#%E5%A4%96%E9%83%A8%E9%93%BE%E6%8E%A5

# %% [markdown]
# 上述程式碼的結果應該是請求失敗，因為缺少「User-Agent」(使用者代理)，
# User-Agent 它屬於Header，是開發者可以自己訂或是更改的(手機APP也可以)，一般來說是用來表明Request發送的「來源程式」，
# 比方說你是用哪種瀏覽器，或是是由哪支APP發出的(要自己定)。並且如果使用的是HTTPS Request的話Header是會被加密的，
# 可以有基本的安全性(但不是很有用，中間人攻擊就是一個例子)，如果只是用HTTP的話則會是明碼傳輸。
#
# 參考自 : https://progressbar.tw/posts/234

# %%
# 加入 Headers 內的 "User-Agent"
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36',
}

# %%
r = requests.get(url, headers=headers)
if r.status_code == 200:
    print(f'請求成功：{r.status_code}')
else:
    print(f'請求失敗：{r.status_code}')
# Out:
# 請求成功：200

# %% [markdown]
# ![ref_1](./ref_imgs/ref_1.png)

# %% [markdown]
# ![ref_2](./ref_imgs/ref_2.png)

# %% [markdown]
# ## 2. 解析網頁元素

# %%
# 印出網頁原始碼
print(r.text)
# Out:
# <!DOCTYPE html>
# <html lang="zh-Hant-TW" data-theme="light">
# <head>
# <title>巴哈姆特動畫瘋</title>
# <meta http-equiv="Content-Type" content="text/html" charset="utf-8">
# <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no">
# <meta name="description" content="動畫瘋是由巴哈姆特所推出，正版授權的免費動畫平台，提供與日本同步的當季新番動畫，並含有高達上萬集的過往名作，供動畫迷們自由選擇！">
# <meta name="thumbnail" content="https://i2.bahamut.com.tw/anime/FB_anime.png">
# <meta property="og:title" content="巴哈姆特動畫瘋">
# <meta property="og:type" content="website">
# <meta property="og:url" content="https://ani.gamer.com.tw">
# <meta property="og:image" content="https://i2.bahamut.com.tw/anime/FB_anime.png">
# <meta property="og:description" content="動畫瘋是由巴哈姆特所推出，正版授權的免費動畫平台，提供與日本同步的當季新番動畫，並含有高達上萬集的過往名作，供動畫迷們自由選擇！">
# <meta name="apple-itunes-app" content="app-id=1102650114">
# <link rel='icon' href='https://i2.bahamut.com.tw/favicon.svg?v=1689129528' type='image/svg+xml'>
# <link rel="apple-touch-icon" href="https://ani.gamer.com.tw/apple-touch-icon-114.jpg" />
# <link rel="apple-touch-icon" sizes="72x72" href="https://ani.gamer.com.tw/apple-touch-icon-72.jpg" />
# <link rel="apple-touch-icon" sizes="144x144" href="https://ani.gamer.com.tw/apple-touch-icon-144.jpg" />
# <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet">
# <link href="https://fonts.googleapis.com/icon?family=Material+Icons+Round" rel="stylesheet">
# <link rel="preconnect" href="https://fonts.gstatic.com">
# <link href="https://fonts.googleapis.com/css2?family=Noto+Sans+TC:wght@100;300;400&display=swap" rel="stylesheet">
# <link href='https://i2.bahamut.com.tw/css/acg_new.css?v=1708312459' rel='stylesheet' type='text/css'>
# <link href='https://i2.bahamut.com.tw/css/anime.css?v=1706497313' rel='stylesheet' type='text/css'>
# <link href="https://i2.bahamut.com.tw/css/plugins/toastr.min.css" rel='stylesheet' type='text/css'>
# <link href="https://i2.bahamut.com.tw/css/font-awesome.css" rel="stylesheet" type="text/css">
# <link href="https://i2.bahamut.com.tw/css/plugins/slick.css?v=1610514513" rel="stylesheet" type="text/css">
# <link href="https://i2.bahamut.com.tw/css/dailybonus.css?v=1694422001" rel="stylesheet" type="text/css">
# <script type="text/javascript" src="https://i2.bahamut.com.tw/js/BAHA_EGG.js"></script>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/2.2.0/jquery.min.js"></script>
# <script type="text/javascript" src="https://i2.bahamut.com.tw/js/plugins/js.cookie-2.1.4.js"></script>
# <script>window.lazySizesConfig = window.lazySizesConfig || {};lazySizesConfig.init = false;</script>
# <script type="text/javascript" src="https://i2.bahamut.com.tw/js/plugins/lazysizes-3.0.0.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/lottie-web/5.10.2/lottie.min.js"></script>
# <script>window.dialogifyConfig = {dialog: {className: 'anime_dialogify'}}</script>
# <script type="text/javascript" src="https://i2.bahamut.com.tw/js/plugins/dialogify.min.js?v=1708584729"></script>
# <script type="text/javascript" src="https://i2.bahamut.com.tw/js/plugins/toastr-2.1.3.min.js"></script>
# <script type="text/javascript" src="https://i2.bahamut.com.tw/js/user_login.js?v=1685524172"></script>
# <script type="text/javascript" src="https://i2.bahamut.com.tw/js/sys.js?v=1602574456"></script>
# <script type="text/javascript" src="https://i2.bahamut.com.tw/js/BH_topBar_ani.js?v=1702975577"></script>
# <script type="text/javascript" src="https://i2.bahamut.com.tw/js/jquery.keyframes.min.js"></script>
# <script type="text/javascript" src="https://i2.bahamut.com.tw/js/anime.js?v=1703645955"></script>
# <script type="text/javascript" src="https://i2.bahamut.com.tw/js/util.js?v=1708484865"></script>
# <script type="text/javascript" src="https://i2.bahamut.com.tw/js/csrf.js?v=1689666161"></script>
# <script type="text/javascript" src="https://i2.bahamut.com.tw/js/plugins/nunjucks-slim-3.2.2.min.js?v=1612340501"></script>
# <script type="text/javascript" src="https://i2.bahamut.com.tw/build/template/signin.min.js?v=1694421412"></script>
# <script type="text/javascript" src="https://i2.bahamut.com.tw/js/signin.js?v=1705976287"></script>
# <script type="text/javascript" src="https://i2.bahamut.com.tw/js/signin_ad.js?v=1692001305"></script>
# <script type='text/javascript' src='https://i2.bahamut.com.tw/js/animeIndex.js?v=1681786066'></script>
# <script type="text/javascript" src="https://i2.bahamut.com.tw/js/ad.js?v=1602819564"></script>
#
#
#
#
#
# <script type="text/javascript" src="https://i2.bahamut.com.tw/JS/ad/animeLogo.js?v=2024022721"></script>
# <script type="text/javascript" src="https://i2.bahamut.com.tw/js/plugins/slick-1.6.0.min.js"></script>
# <script type="text/javascript">
# jQuery(document).ready(function($){
# if( typeof BH_AlkasooD === 'function' ) {
# BH_AlkasooD($);
# }
# });
#
# //anti adblock
# var AntiAd = AntiAd || {};
# (function(AntiAd) {
# 'use strict';
#
# AntiAd.flag = false;
# AntiAd.whiteList = [];
#
# AntiAd.verifyLink = function (link) {}
# AntiAd.block = function() {}
# AntiAd.check = function(element) {}
#
# })(AntiAd);
# </script>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-NDWB6QP');</script>
# <!-- End Google Tag Manager --></head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-NDWB6QP"
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) --><div class="top_sky">
# <div class='sky'>
# <div class="container-player">
# <div class='logo'>
# <a href="//ani.gamer.com.tw"><img src="https://i2.bahamut.com.tw/anime/crazy_logo.png" height="100%"></a>
# </div>
# <div class="anime_search">
# <form id="frm1210" action="search.php" method="POST">
# <div class="anime_search-input">
# <input type="text" id="anime-search-sky" name="keyword" placeholder="請輸入動畫名稱" autocomplete="off">
# <div class="anime_search-icon" onclick="$('#frm1210').submit()">
# <img src="https://i2.bahamut.com.tw/anime/search-icon.svg">
# </div>
# </div>
# </form>
# <div class="anime_search-content">
# <div class="search-content-unit search-recent">
# <div class="tip-title">
# <img src="https://i2.bahamut.com.tw/anime/pic-clock.svg">
# <p>最近搜尋</p>
# <button type="button" class="delete-record-btn">
# <svg width="12" height="16" viewBox="0 0 12 16">
# <path
# d="M8.96.743,8.339.122A.418.418,0,0,0,8.044,0H4.064A.415.415,0,0,0,3.77.122L3.149.743a.416.416,0,0,1-.295.123H.416A.415.415,0,0,0,0,1.282v.9A.416.416,0,0,0,.416,2.6H11.692a.417.417,0,0,0,.417-.417v-.9a.416.416,0,0,0-.417-.416H9.254A.413.413,0,0,1,8.96.743"
# transform="translate(-0.109 0)" fill="#c4c4c4" />
# <path
# d="M1,4V14.38A1.734,1.734,0,0,0,2.73,16.11H9.65a1.735,1.735,0,0,0,1.73-1.729V4Zm4.279,9.867a.753.753,0,1,1-1.506,0V6.243a.753.753,0,1,1,1.506,0Zm3.327,0a.753.753,0,1,1-1.506,0V6.243a.753.753,0,1,1,1.506,0Z"
# transform="translate(-0.244 -0.54)" fill="#c4c4c4" />
# </svg>
# </button>
# </div>
# <div class="search-tag-wrap">
# <div class="search-hint">請先<a href="https://user.gamer.com.tw/login.php">登入會員</a>來顯示搜尋紀錄</div>
#
# </div>
# </div>
# <div class="search-content-unit search-hot">
# <div class="tip-title">
# <img src="https://i2.bahamut.com.tw/anime/pic-fire.svg">
# <p>熱門搜尋</p>
# </div>
# <div class="search-tag-wrap">
# <div class='search-tag keyword'>排球少年</div><div class='search-tag keyword'>肌肉魔法使</div><div class='search-tag keyword'>葬送</div><div class='search-tag keyword'>我獨自升級</div><div class='search-tag keyword'>進擊的巨人</div><div class='search-tag keyword'>咒術迴戰</div><div class='search-tag keyword'>肌肉</div><div class='search-tag keyword'>鬼滅</div><div class='search-tag keyword'>烏龍派出所</div><div class='search-tag keyword'>FATE</div><div class='search-tag keyword'>MYGO</div><div class='search-tag keyword'>JOJO</div><div class='search-tag keyword'>我內心</div><div class='search-tag keyword'>86</div><div class='search-tag keyword'>間諜家家酒</div>
# </div>
# </div>
# <div class="search-content-unit search-filter">
# <div class="btn-filter" onclick="let expire=new Date();expire.setDate(expire.getDate()+360);setCookieNew('ANIME_NEW_ANIME_LIST',1,'gamer.com.tw','/',expire.toGMTString());window.location='https://ani.gamer.com.tw/animeList.php'">
# <div class="img-filter"></div>分類篩選
# <div style="width: 32px;height: 32px;" id="lottieNotice" class="lottie-notice"></div>
# </div>
# </div>
# </div>
# <script type="text/template" id="cleanSearchHistoryConfirm">
# 確定要清除最近搜尋的所有紀錄嗎？
# </script>
# </div>
#
# <script>
#
# document.write('<ul class="member">');
# document.write('<li class="searchbtn"><a href="search.php"><i class="material-icons">search</i></a></li>');
# document.write('<li class="top_btn_notice"><span id="topBar_light_0" style="display:none"></span><a href="javascript:TOPBAR_show(\'light_0\')"></a><span class="tooltip">通知</span></li>');
# document.write('<li class="top_btn_subscription"><span id="topBar_light_1" style="display:none"></span><a href="javascript:TOPBAR_show(\'light_1\')"></a><span class="tooltip">訂閱</span></li>');
# document.write('<li class="top_btn_recommend"><span id="topBar_light_2" style="display:none"></span><a href="javascript:TOPBAR_show(\'light_2\')"></a><span class="tooltip">推薦</span></li>');
# if (User.Login.isLogin()) {
# BAHAID = User.Login.getUserid();
# BAHAIDlow = BAHAID.toLowerCase();
# var avatarUrl = User.Login.getAvatarUrl();
# document.write('<li class="head"><a href="//home.gamer.com.tw/'+BAHAID+'"><img src="' + avatarUrl + '" /></a><span class="tooltip">我的小屋</span></li>');
# NOTIFY_getnum();
# run30 = setInterval("NOTIFY_getnum()",60000);
# }else{
# document.write('<li class="head"><a href="https://user.gamer.com.tw/login.php"><img src="https://i2.bahamut.com.tw/none.gif"></a><span class="tooltip">我要登入</span></li>');
# }
# document.write('<li class="bahago"><a href="//www.gamer.com.tw/" target="_blank"><img alt="" src="https://i2.bahamut.com.tw/anime/baha_s.png"></a><span class="tooltip">回到巴哈</span></li>');
# document.write('</ul>');
#
# document.write('<div id="topBarMsg_light_0" style="display:none"></div>');
# document.write('<div id="topBarMsg_light_1" style="display:none"></div>');
# document.write('<div id="topBarMsg_light_2" style="display:none"></div>');
# document.write('<div id="topBarMsg_hahamut" style="display:none"></div>');
#
# document.write('<div id="topBarMsg_more" style="display:none"></div>');
#
# </script>
# </div>
# </div>
# <nav class="mainmenu on_top">
# <div class="container-player">
# <div class="menu_btn toggle">
# <i class="material-icons">menu</i>
# </div>
# <ul>
# <li><a href="index.php">首頁</a></li>
# <li><a href="animeList.php">所有動畫</a></li>
# <li><a href="viewList.php?u=guest">觀看紀錄</a></li>
# <li><a href="mygather.php">我的動畫</a></li>
# <li><a href="party_entrance.php">動畫派對<img src="https://i2.bahamut.com.tw/anime/beta.svg"></a></li>
# <li class="menu-payment"><a href="animePayRouter.php">付費方案</a></li>
# <li><a href="animeAgeValidate.php">年齡驗證</a></li>
# <li><a href="https://forms.gle/iL4krvy2UwgUd7vFA" target="_blank">問題回報</a></li>
# <li><a href="//prj.gamer.com.tw/app2u/animeapp.html" target="_blank">APP下載</a></li>
# <script>if (User.Login.isLogin()){ document.write(''); }</script>
# </ul>
# <div class="dark-swift-button">
# <input class="swift-btn_toggle" type="checkbox" id="lightSwitch" >
# <label for="lightSwitch">Toggle</label>
# </div>
# </div>
# </nav>
# </div> <!-- End of top_sky-->
#
# <div id="BH_background" class="BH_background"><div class="big_banner"><div class="banner_wrapper"><div class="big_content"><a href="https://ani.gamer.com.tw/animeVideo.php?sn=36858" target="_blank" class="a-mercy-d" data-mercy="7:0" data-si="" data-ssn="250261"><img border=0 src="https://truth.bahamut.com.tw/s01/202402/44f0c33a5a58fccbfd0da007135a44b4.JPG"></a></div></div></div><script> document.cookie = 'ckBahaAd=-------0-----------------;path=/;expires=' + new Date().toDateString() + ' 23:59:59 UTC+0800;domain=.gamer.com.tw' </script><div class="container">
# <div id='blockVideoInSeason' class='newanime-container'>
# <div class='newanime-nav'>
# <div class='nav-segment-control-block'>
# <div class='nav-segment-control nav-choose-segment newanime-switch-page'>
# <p>本季新番</p>
# </div>
# <div class='nav-segment-control textpage-switch-page'>
# <p>週期表</p>
# </div>
# <div class='segment-hover-line'></div>
# </div>
#
# <div class='btn-newanime-filter'>
# <p class='newanime-filter-text'>依更新日排列</p>
# <div class='newanime-filter-icon'></div>
# <ul class='filter-items'>
# <li class='item-newupdate is-active'>依更新日排列</li>
# <li class='item-famous'>依平均人氣排列</li>
# </ul>
# </div>
#
# </div>
#
# <!--依據觀看 開始 -->
# <div class='newanime-wrap timeline-ver'>
# <!-- 列表內文 開始 -->
# <div class='newanime-block'>
#
# <div class='newanime-date-area new-count-1   fadeIn' data-animesn='113449' data-date-code='1'>
# <div class='anime-content-block'>
#
# <div class='date-block'>
# <div class='pic-continue'>
# <img src='https://i2.bahamut.com.tw/anime/pic-continue.svg' alt='icon-continue'>
# </div>
# <div class='date-block-border'></div>
# </div>
#
# <div class='anime-block'>
# <a class='anime-card-block' href='animeVideo.php?sn=
$(this), "btn-is-active"); return false;'></div>
# </div>
# <div class='anime-name-block'>
# <div class='anime-name'>
# <p class=''>香格里拉・開拓異境～糞作獵手挑戰神作～</p>
# <p class='anime-name_for-marquee'>香格里拉・開拓異境～糞作獵手挑戰神作～</p>
# </div>
# <div class='anime-watch-number'>
# <i class='pic-eye-style material-icons'>remove_red_eye</i>
# <p>486.9萬</p>
# </div>
# </div>
# </a>
# </div>
# </div>
#
# <span class='anime-date-info anime-date-info-block-arrow'>
#
# <svg class='anime-date_svg-is-active' viewBox='0 0 82 28'>
# <title>svg_is_active</title>
# <g fill='none' fill-rule='evenodd'>
# <g class='anime-date-info_is-active'>
# <path d='M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z'></path>
# </g>
# </g>
# </svg>
#
# 02/25 (日)
# </span>
#
# </div>
#
# <div class='newanime-date-area new-count-3   fadeIn' data-animesn='113400' data-date-code='3'>
# <div class='anime-content-block'>
#
# <div class='date-block'>
# <div class='pic-continue'>
# <img src='https://i2.bahamut.com.tw/anime/pic-continue.svg' alt='icon-continue'>
# </div>
# <div class='date-block-border'></div>
# </div>
#
# <div class='anime-block'>
# <a class='anime-card-block' href='animeVideo.php?sn=37347' data-gtm='本季新番卡片'>
# <div class='anime-pic-block'>
#
# <div class='anime-hours-block'>
# <img class='anime-clock-img' src='https://i2.bahamut.com.tw/anime/pic_time_icon.svg' alt='clock_img'>
# <span class='anime-hours'>11:00</span>
# </div>
#
# <div class='anime-blocker'>
# <img class='lazyload' data-src='https://p2.bahamut.com.tw/B/2KU/00/01431699f697b87d756cbcc6d81p0ls5.JPG' alt='anime_pic'>
# </div>
# <div class='line-gradient'></div>
# <div class='anime-detail-info-block'>
# <div class='anime-episode'>
# <img src='https://i2.bahamut.com.tw/anime/pic-tv.svg' alt='pic-tv'><p>第18集</p>
# </div>
# <div class='anime-label-block'>
#
# </div>
# </div>
# <div class='btn-card-block btn-favorite btn-not-active ' onclick='animefun.toggleGather(135403, 113400, $(this), "btn-is-active"); return false;'></div>
# </div>
# <div class='anime-name-block'>
# <div class='anime-name'>
# <p class=''>小不點</p>
# <p class='anime-name_for-marquee'>小不點</p>
# </div>
# <div class='anime-watch-number'>
# <i class='pic-eye-style material-icons'>remove_red_eye</i>
# <p>3.1萬</p>
# </div>
# </div>
# </a>
# </div>
# </div>
#
# <span class='anime-date-info anime-date-info-block-arrow'>
#
# <svg class='anime-date_svg-is-active' viewBox='0 0 82 28'>
# <title>svg_is_active</title>
# <g fill='none' fill-rule='evenodd'>
# <g class='anime-date-info_is-active'>
# <path d='M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z'></path>
# </g>
# </g>
# </svg>
#
# 02/25 (日)
# </span>
#
# </div>
#
# <div class='newanime-date-area new-count-3   fadeIn' data-animesn='113460' data-date-code='3'>
# <div class='anime-content-block'>
#
# <div class='date-block'>
# <div class='pic-continue'>
# <img src='https://i2.bahamut.com.tw/anime/pic-continue.svg' alt='icon-continue'>
# </div>
# <div class='date-block-border'></div>
# </div>
#
# <div class='anime-block'>
# <a class='anime-card-block' href='animeVideo.php?sn=37348' data-gtm='本季新番卡片'>
# <div class='anime-pic-block'>
#
# <div class='anime-hours-block'>
# <img class='anime-clock-img' src='https://i2.bahamut.com.tw/anime/pic_time_icon.svg' alt='clock_img'>
# <span class='anime-hours'>02:00</span>
# </div>
#
# <div class='anime-blocker'>
# <img class='lazyload' data-src='https://p2.bahamut.com.tw/B/2KU/96/8bc8988c582cc3de8ef5d4eaeb1p0lo5.JPG' alt='anime_pic'>
# </div>
# <div class='line-gradient'></div>
# <div class='anime-detail-info-block'>
# <div class='anime-episode'>
# <img src='https://i2.bahamut.com.tw/anime/pic-tv.svg' alt='pic-tv'><p>第20集</p>
# </div>
# <div class='anime-label-block'>
#
# </div>
# </div>
# <div class='btn-card-block btn-favorite btn-not-active ' onclick='animefun.toggleGather(133422, 113460, $(this), "btn-is-active"); return false;'></div>
# </div>
# <div class='anime-name-block'>
# <div class='anime-name'>
# <p class=''>我內心的糟糕念頭 第二季</p>
# <p class='anime-name_for-marquee'>我內心的糟糕念頭 第二季</p>
# </div>
# <div class='anime-watch-number'>
# <i class='pic-eye-style material-icons'>remove_red_eye</i>
# <p>112.5萬</p>
# </div>
# </div>
# </a>
# </div>
# </div>
#
# <span class='anime-date-info anime-date-info-block-arrow'>
#
# <svg class='anime-date_svg-is-active' viewBox='0 0 82 28'>
# <title>svg_is_active</title>
# <g fill='none' fill-rule='evenodd'>
# <g class='anime-date-info_is-active'>
# <path d='M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z'></path>
# </g>
# </g>
# </svg>
#
# 02/25 (日)
# </span>
#
# </div>
#
# <div class='newanime-date-area new-count-3   fadeIn' data-animesn='113447' data-date-code='3'>
# <div class='anime-content-block'>
#
# <div class='date-block'>
# <div class='pic-continue'>
# <img src='https://i2.bahamut.com.tw/anime/pic-continue.svg' alt='icon-continue'>
# </div>
# <div class='date-block-border'></div>
# </div>
#
# <div class='anime-block'>
# <a class='anime-card-block' href='animeVideo.php?sn=37349' data-gtm='本季新番卡片'>
# <div class='anime-pic-block'>
#
# <div class='anime-hours-block'>
# <img class='anime-clock-img' src='https://i2.bahamut.com.tw/anime/pic_time_icon.svg' alt='clock_img'>
# <span class='anime-hours'>01:30</span>
# </div>
#
# <div class='anime-blocker'>
# <img class='lazyload' data-src='https://p2.bahamut.com.tw/B/2KU/94/0cbbed28a95ea8c261d95c76b81p0ty5.JPG' alt='anime_pic'>
# </div>
# <div class='line-gradient'></div>
# <div class='anime-detail-info-block'>
# <div class='anime-episode'>
# <img src='https://i2.bahamut.com.tw/anime/pic-tv.svg' alt='pic-tv'><p>第8集</p>
# </div>
# <div class='anime-label-block'>
#
# </div>
# </div>
# <div class='btn-card-block btn-favorite btn-not-active ' onclick='animefun.toggleGather(135895, 113447, $(this), "btn-is-active"); return false;'></div>
# </div>
# <div class='anime-name-block'>
# <div class='anime-name'>
# <p class=''>最強肉盾的迷宮攻略～擁有稀少技能體力 9999 的肉盾，被勇者隊伍辭退了～</p>
# <p class='anime-name_for-marquee'>最強肉盾的迷宮攻略～擁有稀少技能體力 9999 的肉盾，被勇者隊伍辭退了～</p>
# </div>
# <div class='anime-watch-number'>
# <i class='pic-eye-style material-icons'>remove_red_eye</i>
# <p>70.3萬</p>
# </div>
# </div>
# </a>
# </div>
# </div>
#
# <span class='anime-date-info anime-date-info-block-arrow'>
#
# <svg class='anime-date_svg-is-active' viewBox='0 0 82 28'>
# <title>svg_is_active</title>
# <g fill='none' fill-rule='evenodd'>
# <g class='anime-date-info_is-active'>
# <path d='M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z'></path>
# </g>
# </g>
# </svg>
#
# 02/25 (日)
# </span>
#
# </div>
#
# <div class='newanime-date-area new-count-3   fadeIn' data-animesn='113459' data-date-code='3'>
# <div class='anime-content-block'>
#
# <div class='date-block'>
# <div class='pic-continue'>
# <img src='https://i2.bahamut.com.tw/anime/pic-continue.svg' alt='icon-continue'>
# </div>
# <div class='date-block-border'></div>
# </div>
#
# <div class='anime-block'>
# <a class='anime-card-block' href='animeVideo.php?sn=37350' data-gtm='本季新番卡片'>
# <div class='anime-pic-block'>
#
# <div class='anime-hours-block'>
# <img class='anime-clock-img' src='https://i2.bahamut.com.tw/anime/pic_time_icon.svg' alt='clock_img'>
# <span class='anime-hours'>01:00</span>
# </div>
#
# <div class='anime-blocker'>
# <img class='lazyload' data-src='https://p2.bahamut.com.tw/B/2KU/93/cb5bd921a537dd3d95c8bdfb721p0tx5.JPG' alt='anime_pic'>
# </div>
# <div class='line-gradient'></div>
# <div class='anime-detail-info-block'>
# <div class='anime-episode'>
# <img src='https://i2.bahamut.com.tw/anime/pic-tv.svg' alt='pic-tv'><p>第8集</p>
# </div>
# <div class='anime-label-block'>
#
# </div>
# </div>
# <div class='btn-card-block btn-favorite btn-not-active ' onclick='animefun.toggleGather(129285, 113459, $(this), "btn-is-active"); return false;'></div>
# </div>
# <div class='anime-name-block'>
# <div class='anime-name'>
# <p class=''>青之驅魔師 島根啟明結社篇</p>
# <p class='anime-name_for-marquee'>青之驅魔師 島根啟明結社篇</p>
# </div>
# <div class='anime-watch-number'>
# <i class='pic-eye-style material-icons'>remove_red_eye</i>
# <p>30萬</p>
# </div>
# </div>
# </a>
# </div>
# </div>
#
# <span class='anime-date-info anime-date-info-block-arrow'>
#
# <svg class='anime-date_svg-is-active' viewBox='0 0 82 28'>
# <title>svg_is_active</title>
# <g fill='none' fill-rule='evenodd'>
# <g class='anime-date-info_is-active'>
# <path d='M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z'></path>
# </g>
# </g>
# </svg>
#
# 02/25 (日)
# </span>
#
# </div>
#
# <div class='newanime-date-area new-count-3   fadeIn' data-animesn='113458' data-date-code='3'>
# <div class='anime-content-block'>
#
# <div class='date-block'>
# <div class='pic-continue'>
# <img src='https://i2.bahamut.com.tw/anime/pic-continue.svg' alt='icon-continue'>
# </div>
# <div class='date-block-border'></div>
# </div>
#
# <div class='anime-block'>
# <a class='anime-card-block' href='animeVideo.php?sn=37351' data-gtm='本季新番卡片'>
# <div class='anime-pic-block'>
#
# <div class='anime-hours-block'>
# <img class='anime-clock-img' src='https://i2.bahamut.com.tw/anime/pic_time_icon.svg' alt='clock_img'>
# <span class='anime-hours'>00:30</span>
# </div>
#
# <div class='anime-blocker'>
# <img class='lazyload' data-src='https://p2.bahamut.com.tw/B/2KU/89/d88885ca99cb091e02710a63291p0lh5.JPG' alt='anime_pic'>
# </div>
# <div class='line-gradient'></div>
# <div class='anime-detail-info-block'>
# <div class='anime-episode'>
# <img src='https://i2.bahamut.com.tw/anime/pic-tv.svg' alt='pic-tv'><p>第7.5集</p>
# </div>
# <div class='anime-label-block'>
#
# </div>
# </div>
# <div class='btn-card-block btn-favorite btn-not-active ' onclick='animefun.toggleGather(125545, 113458, $(this), "btn-is-active"); return false;'></div>
# </div>
# <div class='anime-name-block'>
# <div class='anime-name'>
# <p class=''>我獨自升級</p>
# <p class='anime-name_for-marquee'>我獨自升級</p>
# </div>
# <div class='anime-watch-number'>
# <i class='pic-eye-style material-icons'>remove_red_eye</i>
# <p>217.1萬</p>
# </div>
# </div>
# </a>
# </div>
# </div>
#
# <span class='anime-date-info anime-date-info-block-arrow'>
#
# <svg class='anime-date_svg-is-active' viewBox='0 0 82 28'>
# <title>svg_is_active</title>
# <g fill='none' fill-rule='evenodd'>
# <g class='anime-date-info_is-active'>
# <path d='M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z'></path>
# </g>
# </g>
# </svg>
#
# 02/25 (日)
# </span>
#
# </div>
#
# <div class='newanime-date-area new-count-3   fadeIn' data-animesn='113378' data-date-code='3'>
# <div class='anime-content-block'>
#
# <div class='date-block'>
# <div class='pic-continue'>
# <img src='https://i2.bahamut.com.tw/anime/pic-continue.svg' alt='icon-continue'>
# </div>
# <div class='date-block-border'></div>
# </div>
#
# <div class='anime-block'>
# <a class='anime-card-block' href='animeVideo.php?sn=37352' data-gtm='本季新番卡片'>
# <div class='anime-pic-block'>
#
# <div class='anime-hours-block'>
# <img class='anime-clock-img' src='https://i2.bahamut.com.tw/anime/pic_time_icon.svg' alt='clock_img'>
# <span class='anime-hours'>00:00</span>
# </div>
#
# <div class='anime-blocker'>
# <img class='lazyload' data-src='https://p2.bahamut.com.tw/B/2KU/86/33c4cd852e78af90c8851bca2b1p0le5.JPG' alt='anime_pic'>
# </div>
# <div class='line-gradient'></div>
# <div class='anime-detail-info-block'>
# <div class='anime-episode'>
# <img src='https://i2.bahamut.com.tw/anime/pic-tv.svg' alt='pic-tv'><p>第19集</p>
# </div>
# <div class='anime-label-block'>
#
# </div>
# </div>
# <div class='btn-card-block btn-favorite btn-not-active ' onclick='animefun.toggleGather(123490, 113378, $(this), "btn-is-active"); return false;'></div>
# </div>
# <div class='anime-name-block'>
# <div class='anime-name'>
# <p class=''>狩龍人拉格納</p>
# <p class='anime-name_for-marquee'>狩龍人拉格納</p>
# </div>
# <div class='anime-watch-number'>
# <i class='pic-eye-style material-icons'>remove_red_eye</i>
# <p>170.3萬</p>
# </div>
# </div>
# </a>
# </div>
# </div>
#
# <span class='anime-date-info anime-date-info-block-arrow'>
#
# <svg class='anime-date_svg-is-active' viewBox='0 0 82 28'>
# <title>svg_is_active</title>
# <g fill='none' fill-rule='evenodd'>
# <g class='anime-date-info_is-active'>
# <path d='M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z'></path>
# </g>
# </g>
# </svg>
#
# 02/25 (日)
# </span>
#
# </div>
#
# <div class='newanime-date-area new-count-3   fadeIn' data-animesn='113457' data-date-code='3'>
# <div class='anime-content-block'>
#
# <div class='date-block'>
# <div class='pic-continue'>
# <img src='https://i2.bahamut.com.tw/anime/pic-continue.svg' alt='icon-continue'>
# </div>
# <div class='date-block-border'></div>
# </div>
#
# <div class='anime-block'>
# <a class='anime-card-block' href='animeVideo.php?sn=37227' data-gtm='本季新番卡片'>
# <div class='anime-pic-block'>
#
# <div class='anime-hours-block'>
# <img class='anime-clock-img' src='https://i2.bahamut.com.tw/anime/pic_time_icon.svg' alt='clock_img'>
# <span class='anime-hours'>00:00</span>
# </div>
#
# <div class='anime-blocker'>
# <img class='lazyload' data-src='https://p2.bahamut.com.tw/B/2KU/87/cc088949b7fff99f2531833b251p0lf5.JPG' alt='anime_pic'>
# </div>
# <div class='line-gradient'></div>
# <div class='anime-detail-info-block'>
# <div class='anime-episode'>
# <img src='https://i2.bahamut.com.tw/anime/pic-tv.svg' alt='pic-tv'><p>第19集</p>
# </div>
# <div class='anime-label-block'>
#
# </div>
# </div>
# <div class='btn-card-block btn-favorite btn-not-active ' onclick='animefun.toggleGather(133792, 113457, $(this), "btn-is-active"); return false;'></div>
# </div>
# <div class='anime-name-block'>
# <div class='anime-name'>
# <p class=''>肌肉魔法使-MASHLE- 神覺者候補選拔試驗篇</p>
# <p class='anime-name_for-marquee'>肌肉魔法使-MASHLE- 神覺者候補選拔試驗篇</p>
# </div>
# <div class='anime-watch-number'>
# <i class='pic-eye-style material-icons'>remove_red_eye</i>
# <p>136.1萬</p>
# </div>
# </div>
# </a>
# </div>
# </div>
#
# <span class='anime-date-info anime-date-info-block-arrow'>
#
# <svg class='anime-date_svg-is-active' viewBox='0 0 82 28'>
# <title>svg_is_active</title>
# <g fill='none' fill-rule='evenodd'>
# <g class='anime-date-info_is-active'>
# <path d='M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z'></path>
# </g>
# </g>
# </svg>
#
# 02/25 (日)
# </span>
#
# </div>
#
# <div class='newanime-date-area new-count-4   fadeIn' data-animesn='113440' data-date-code='4'>
# <div class='anime-content-block'>
#
# <div class='date-block'>
# <div class='pic-continue'>
# <img src='https://i2.bahamut.com.tw/anime/pic-continue.svg' alt='icon-continue'>
# </div>
# <div class='date-block-border'></div>
# </div>
#
# <div class='anime-block'>
# <a class='anime-card-block' href='animeVideo.php?sn=37354' data-gtm='本季新番卡片'>
# <div class='anime-pic-block'>
#
# <div class='anime-hours-block'>
# <img class='anime-clock-img' src='https://i2.bahamut.com.tw/anime/pic_time_icon.svg' alt='clock_img'>
# <span class='anime-hours'>21:30</span>
# </div>
#
# <div class='anime-blocker'>
# <img class='lazyload' data-src='https://p2.bahamut.com.tw/B/2KU/85/a2889aac3b99f902d3262757bb1p0ld5.JPG' alt='anime_pic'>
# </div>
# <div class='line-gradient'></div>
# <div class='anime-detail-info-block'>
# <div class='anime-episode'>
# <img src='https://i2.bahamut.com.tw/anime/pic-tv.svg' alt='pic-tv'><p>第8集</p>
# </div>
# <div class='anime-label-block'>
#
# </div>
# </div>
# <div class='btn-card-block btn-favorite btn-not-active ' onclick='animefun.toggleGather(133896, 113440, $(this), "btn-is-active"); return false;'></div>
# </div>
# <div class='anime-name-block'>
# <div class='anime-name'>
# <p class=''>指尖相觸，戀戀不捨</p>
# <p class='anime-name_for-marquee'>指尖相觸，戀戀不捨</p>
# </div>
# <div class='anime-watch-number'>
# <i class='pic-eye-style material-icons'>remove_red_eye</i>
# <p>31.1萬</p>
# </div>
# </div>
# </a>
# </div>
# </div>
#
# <span class='anime-date-info anime-date-info-block-arrow'>
#
# <svg class='anime-date_svg-is-active' viewBox='0 0 82 28'>
# <title>svg_is_active</title>
# <g fill='none' fill-rule='evenodd'>
# <g class='anime-date-info_is-active'>
# <path d='M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 
# </div>
# <div class='extend-content-block'>
# <h3 class='extend-title'>
# 【情報】《OVERLORD》『劇場版聖王國編』 視覺圖 第2弾公開&amp; AnimeJapan 2024視覺圖及商品情報
# </h3>
# <p class='extend-content'>
# オーバーロード／アニメ公式@over_lord_anime◤￣￣￣￣￣￣￣￣￣￣￣　　　　　　　　　　　アインズ死す――
# </p>
# <div class='btn-read-more'>
# <p>繼續閱讀</p>
# </div>
# </div>
# </a>
#
# </div>
# </div>
# </div></div>
#
# <div class="footer">
# <div class="footer-topline"></div>
# <div class="footer-content">
# <div class="footer-text">
# <p>旺普網路資訊股份有限公司 <span>© Oneup Network Corporation All Rights Reserved.</span></p>
# <p><a href="https://ani.gamer.com.tw/animeRule.php">服務條款</a>｜<a href="https://user.gamer.com.tw/help/tellus.php?c1=3">合作提案</a>｜本網站已依台灣網站內容分級規定處理｜<span>法律顧問: 益思科技法律事務所</span></p>
# </div>
# <div class="ott-icon">
# <!-- <img src="https://i2.bahamut.com.tw/anime/OTT_black.svg"> -->
# <div class="ott-img"></div>
# </div>
# <div class="footer-separate-line"></div>
# <div class="footer-aniapp">
# <div class="app-download">
# <a class="ios" href="https://apps.apple.com/tw/app/id1102650114?l=zh"><img src="https://i2.bahamut.com.tw/anime/AppleStore.svg"></a>
# <a class="android" href="https://play.google.com/store/apps/details?id=tw.com.gamer.android.animad&hl=zh_TW&referrer=utm_source%3Dapp2u%26utm_medium%3Dpromotion"><img src="https://i2.bahamut.com.tw/anime/GoogleStore.svg"></a>
# </div>
# <div class="ani-qrcode">
# <img src="https://i2.bahamut.com.tw/anime/appQR.png">
# <p style="font-size:9px">下載 APP</p>
# </div>
# </div>
# </div>
# </div><div
# style="
# position: fixed;
# left: 20px;
# right: 20px;
# bottom: 20px;
# z-index: 99;
# display: none;
# padding: 15px 30px 15px 15px;
# border: 1px solid transparent;
# border-radius: 3px;
# line-height: 1.5;
# background: #FFFFDB;
# border-color: #E1D3B8;
# color: #705930;">
# <a href="javascript:;" class="alert-close">
# <i class="material-icons">close</i>
# </a>
# <p style="color: #705930;font-size: 1.4em; padding: 0;"><i class="material-icons" style="vertical-align: middle; font-size: 1.6em; margin-right: 5px;">face</i>我們了解您不想看到廣告的心情⋯ 若您願意支持巴哈姆特永續經營，請將 gamer.com.tw 加入廣告阻擋工具的白名單中，謝謝 !<a href="https://goo.gl/PmkwWS" style="color: #0055aa;text-decoration: none;" target="_blank;">【教學】</a></p>
# </div>
#
# <script>
# jQuery(".a-mercy-d").click(function() {
# var url = this.href;
# var goRedirect = false;
# var openNew = (this.target) ? true : false;
#
# if( url ) {
# jQuery.get( "/ajax/baha_lkasoo.php", { id: jQuery(this).data('ssn') } )
# .done(function() {
# goRedirect = true;
# if( !openNew ){
# document.location = url;
# }
# });
#
# setTimeout(function() {
# if (!goRedirect) {
# if( !openNew ){
# document.location = url;
# }
# }
# }, 1500);
# }
#
# if( !openNew ){
# return false;
# }
# });
#
# var mercyadblock = (function () {
# var adblock = {};
#
# adblock.show = function () {
# jQuery('.alert-close').parent().show();
# };
#
# adblock.hide = function () {
# jQuery('.alert-close').parent().hide();
# };
#
# adblock.check = function () {
# if (localStorage.getItem('admercyblocks') === null) {
# jQuery('.alert-close').parent().show();
# } else {
# var hourts = Math.floor(Date.now() / 1000)-86400;
# if (localStorage.getItem('admercyblocks') < hourts) {
# jQuery('.alert-close').parent().show();
# localStorage.removeItem('admercyblocks');
# }
# }
# };
#
# return adblock;
# } ());
#
# if (typeof(Storage) === "undefined") {
# /*load fail*/
# if (typeof antiadb === 'undefined') {
# mercyadblock.show();
# } else {
# /*load success but open*/
# antiadb.onDetected(function () {
# mercyadblock.show();
# });
# }
# } else {
# /*load fail*/
# if (typeof antiadb === 'undefined') {
# mercyadblock.check();
# } else {
# /*load success but open*/
# antiadb.onDetected(function(){
# mercyadblock.check();
# });
# }
# }
#
# jQuery(".alert-close").click(function() {
# mercyadblock.hide();
#
# if (typeof(Storage) !== "undefined") {
# localStorage.setItem('admercyblocks', Math.floor(Date.now() / 1000));
# }
# });
#
# </script>
# <script>
# $('#BH_background').click(function(){
# $('#topBarMsg_'+topBarType).css('display','none');
# $('#topBar_'+topBarType).parent().removeClass('is-active');
# });
#
# $(".mainmenu .toggle").click(function() {
# $(this).toggleClass("active");
# $(".mainmenu ul").slideToggle(0);
# });
#
# $(window).resize( function(){
# $(".mainmenu ul").removeAttr('style');
# });
#
# animefun.notSupportedMsg(0);
# </script>

# %%
# 解析原始碼，可用內建的解析器 html.parser 或是用 html5lib
# 解析氣的差別可看 : https://blog.csdn.net/weixin_45954198/article/details/123964809
soup = BeautifulSoup(r.text, "html5lib")

# %%
# 抓取 class 有包含 timeline-ver 元素底下一層 class 有包含 newanime-block 的元素
newanime_item = soup.select_one('.timeline-ver > .newanime-block')

# %%
# 會發現當中的下一層可抓到每一個動畫資料元素
print(newanime_item)
# Out:
# <div class="newanime-block">
#
# <div class="newanime-date-area new-count-1 fadeIn" data-animesn="113449" data-date-code="1">
# <div class="anime-content-block">
#
# <div class="date-block">
# <div class="pic-continue">
# <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
# </div>
# <div class="date-block-border"></div>
# </div>
#
# <div class="anime-block">
# <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=37367">
# <div class="anime-pic-block">
#
# <div class="anime-hours-block">
# <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
# <span class="anime-hours">00:30</span>
# </div>
#
# <div class="anime-blocker">
# <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/32/29526e237be2842d21286a4bc51p13c5.JPG"/>
# </div>
# <div class="line-gradient"></div>
# <div class="anime-detail-info-block">
# <div class="anime-episode">
# <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第8集</p>
# </div>
# <div class="anime-label-block">
# <span class="label-edition color-paid">付費會員</span>
# </div>
# </div>
# <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(133647, 113449, $(this), "btn-is-active"); return false;'></div>
# </div>
# <div class="anime-name-block">
# <div class="anime-name">
# <p class="">公主殿下，「拷問」的時間到了</p>
# <p class="anime-name_for-marquee">公主殿下，「拷問」的時間到了</p>
# </div>
# <div class="anime-watch-number">
# <i class="pic-eye-style material-icons">remove_red_eye</i>
# <p>30萬</p>
# </div>
# </div>
# </a>
# </div>
# </div>
#
# <span class="anime-date-info anime-date-info-block-arrow">
#
# <svg class="anime-date_svg-is-active" viewBox="0 0 82 28">
# <title>svg_is_active</title>
# <g fill="none" fill-rule="evenodd">
# <g class="anime-date-info_is-active">
# <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
# </g>
# </g>
# </svg>
#
# 02/27 (二)
# </span>
#
# <span class="anime-date-info anime-date-info-block-rectangle">
#
# <svg class="anime-date_svg-not-active" viewBox="0 0 82 28">
# <title>svg_not_active</title>
# <g fill="none" fill-rule="evenodd">
# <g class="anime-date-info_not-active">
# <path d="M4,0 L78,0 A4,4 0 0 1 82,4 L82,24 A4,4 0 0 1 78,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
# </g>
# </g>
# </svg>
#
# 02/27 (二)
# </span>
#
# </div>
#
# <div class="newanime-date-area new-count-1 fadeIn" data-animesn="113454" data-date-code="1">
# <div class="anime-content-block">
#
# <div class="date-block">
# <div class="pic-continue">
# <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
# </div>
# <div class="date-block-border"></div>
# </div>
#
# <div class="anime-block">
# <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=37368">
# <div class="anime-pic-block">
#
# <div class="anime-hours-block">
# <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
# <span class="anime-hours">00:30</span>
# </div>
#
# <div class="anime-blocker">
# <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/25/bb06e515f0d5c7c21a0633e45d1p1355.JPG"/>
# </div>
# <div class="line-gradient"></div>
# <div class="anime-detail-info-block">
# <div class="anime-episode">
# <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第8集</p>
# </div>
# <div class="anime-label-block">
#
# </div>
# </div>
# <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(131988, 113454, $(this), "btn-is-active"); return false;'></div>
# </div>
# <div class="anime-name-block">
# <div class="anime-name">
# <p class="">愚蠢天使與惡魔共舞</p>
# <p class="anime-name_for-marquee">愚蠢天使與惡魔共舞</p>
# </div>
# <div class="anime-watch-number">
# <i class="pic-eye-style material-icons">remove_red_eye</i>
# <p>36.5萬</p>
# </div>
# </div>
# </a>
# </div>
# </div>
#
# <span class="anime-date-info anime-date-info-block-arrow">
#
# <svg class="anime-date_svg-is-active" viewBox="0 0 82 28">
# <title>svg_is_active</title>
# <g fill="none" fill-rule="evenodd">
# <g class="anime-date-info_is-active">
# <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
# </g>
# </g>
# </svg>
#
# 02/27 (二)
# </span>
#
# </div>
#
# <div class="newanime-date-area new-count-2 fadeIn" data-animesn="113470" data-date-code="2">
# <div class="anime-content-block">
#
# <div class="date-block">
# <div class="pic-continue">
# <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
# </div>
# <div class="date-block-border"></div>
# </div>
#
# <div class="anime-block">
# <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=37369">
# <div class="anime-pic-block">
#
# <div class="anime-hours-block">
# <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
# <span class="anime-hours">23:00</span>
# </div>
#
# <div class="anime-blocker">
# <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/91/36135992dc6b1024f362b570611p14z5.JPG"/>
# </div>
# <div class="line-gradient"></div>
# <div class="anime-detail-info-block">
# <div class="anime-episode">
# <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第8集</p>
# </div>
# <div class="anime-label-block">
#
# </div>
# </div>
# <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(119792, 113470, $(this), "btn-is-active"); return false;'></div>
# </div>
# <div class="anime-name-block">
# <div class="anime-name">
# <p class="">月光下的異世界之旅 第二季</p>
# <p class="anime-name_for-marquee">月光下的異世界之旅 第二季</p>
# </div>
# <div class="anime-watch-number">
# <i class="pic-eye-style material-icons">remove_red_eye</i>
# <p>97.5萬</p>
# </div>
# </div>
# </a>
# </div>
# </div>
#
# <span class="anime-date-info anime-date-info-block-arrow">
#
# <svg class="anime-date_svg-is-active" viewBox="0 0 82 28">
# <title>svg_is_active</title>
# <g fill="none" fill-rule="evenodd">
# <g class="anime-date-info_is-active">
# <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
# </g>
# </g>
# </svg>
#
# 02/26 (一)
# </span>
#
# <span class="anime-date-info anime-date-info-block-rectangle">
#
# <svg class="anime-date_svg-not-active" viewBox="0 0 82 28">
# <title>svg_not_active</title>
# <g fill="none" fill-rule="evenodd">
# <g class="anime-date-info_not-active">
# <path d="M4,0 L78,0 A4,4 0 0 1 82,4 L82,24 A4,4 0 0 1 78,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
# </g>
# </g>
# </svg>
#
# 02/26 (一)
# </span>
#
# </div>
#
# <div class="newanime-date-area new-count-2 fadeIn" data-animesn="113407" data-date-code="2">
# <div class="anime-content-block">
#
# <div class="date-block">
# <div class="pic-continue">
# <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
# </div>
# <div class="date-block-border"></div>
# </div>
#
# <div class="anime-block">
# <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=37371">
# <div class="anime-pic-block">
#
# <div class="anime-hours-block">
# <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
# <span class="anime-hours">20:00</span>
# </div>
#
# <div class="anime-blocker">
# <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/81/f78eb1beef365c44841d790b3b1p0z55.JPG"/>
# </div>
# <div class="line-gradient"></div>
# <div class="anime-detail-info-block">
# <div class="anime-episode">
# <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第17集</p>
# </div>
# <div class="anime-label-block">
#
# </div>
# </div>
# <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(134389, 113407, $(this), "btn-is-active"); return false;'></div>
# </div>
# <div class="anime-name-block">
# <div class="anime-name">
# <p class="">愛犬訊號</p>
# <p class="anime-name_for-marquee">愛犬訊號</p>
# </div>
# <div class="anime-watch-number">
# <i class="pic-eye-style material-icons">remove_red_eye</i>
# <p>8萬</p>
# </div>
# </div>
# </a>
# </div>
# </div>
#
# <span class="anime-date-info anime-date-info-block-arrow">
#
# <svg class="anime-date_svg-is-active" viewBox="0 0 82 28">
# <title>svg_is_active</title>
# <g fill="none" fill-rule="evenodd">
# <g class="anime-date-info_is-active">
# <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
# </g>
# </g>
# </svg>
#
# 02/26 (一)
# </span>
#
# </div>
#
# <div class="newanime-date-area new-count-2 fadeIn" data-animesn="113464" data-date-code="2">
# <div class="anime-content-block">
#
# <div class="date-block">
# <div class="pic-continue">
# <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
# </div>
# <div class="date-block-border"></div>
# </div>
#
# <div class="anime-block">
# <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=37447">
# <div class="anime-pic-block">
#
# <div class="anime-hours-block">
# <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
# <span class="anime-hours

# </span>
#
# <span class="anime-date-info anime-date-info-block-rectangle">
#
# <svg class="anime-date_svg-not-active" viewBox="0 0 82 28">
# <title>svg_not_active</title>
# <g fill="none" fill-rule="evenodd">
# <g class="anime-date-info_not-active">
# <path d="M4,0 L78,0 A4,4 0 0 1 82,4 L82,24 A4,4 0 0 1 78,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
# </g>
# </g>
# </svg>
#
# 01/21 (日)
# </span>
#
# </div>
#
# <div class="premium-block newanime-date-area newanime-content-hide fadeIn">
# <div class="premium-info">
# <div class="premium-info--count">
# <div class="premium-info__title">
# <span class="heading">付費比例</span>
# <span class="number">13.73</span>
# </div>
# </div>
# <div class="premium-info--intro">
# <p>付費比例是以目前付費會員數量與30日內不重複之觀眾總數計算，本數值每日更新一次。</p>
# </div>
# </div>
# </div>
# <div class="anime-btn-show-more">
# <span class="btn-show-more">展開更多</span>
# </div>
# </div>

# %%
# 再往下一層可抓到每一個動畫資料元素，決定用 newanime-date-area 定位
anime_items = newanime_item.select('.newanime-date-area')

# %%
print(anime_items)
# Out:
# [<div class="newanime-date-area new-count-1 fadeIn" data-animesn="113449" data-date-code="1">
# <div class="anime-content-block">
#
# <div class="date-block">
# <div class="pic-continue">
# <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
# </div>
# <div class="date-block-border"></div>
# </div>
#
# <div class="anime-block">
# <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=37367">
# <div class="anime-pic-block">
#
# <div class="anime-hours-block">
# <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
# <span class="anime-hours">00:30</span>
# </div>
#
# <div class="anime-blocker">
# <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/32/29526e237be2842d21286a4bc51p13c5.JPG"/>
# </div>
# <div class="line-gradient"></div>
# <div class="anime-detail-info-block">
# <div class="anime-episode">
# <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第8集</p>
# </div>
# <div class="anime-label-block">
# <span class="label-edition color-paid">付費會員</span>
# </div>
# </div>
# <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(133647, 113449, $(this), "btn-is-active"); return false;'></div>
# </div>
# <div class="anime-name-block">
# <div class="anime-name">
# <p class="">公主殿下，「拷問」的時間到了</p>
# <p class="anime-name_for-marquee">公主殿下，「拷問」的時間到了</p>
# </div>
# <div class="anime-watch-number">
# <i class="pic-eye-style material-icons">remove_red_eye</i>
# <p>30萬</p>
# </div>
# </div>
# </a>
# </div>
# </div>
#
# <span class="anime-date-info anime-date-info-block-arrow">
#
# <svg class="anime-date_svg-is-active" viewBox="0 0 82 28">
# <title>svg_is_active</title>
# <g fill="none" fill-rule="evenodd">
# <g class="anime-date-info_is-active">
# <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
# </g>
# </g>
# </svg>
#
# 02/27 (二)
# </span>
#
# <span class="anime-date-info anime-date-info-block-rectangle">
#
# <svg class="anime-date_svg-not-active" viewBox="0 0 82 28">
# <title>svg_not_active</title>
# <g fill="none" fill-rule="evenodd">
# <g class="anime-date-info_not-active">
# <path d="M4,0 L78,0 A4,4 0 0 1 82,4 L82,24 A4,4 0 0 1 78,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
# </g>
# </g>
# </svg>
#
# 02/27 (二)
# </span>
#
# </div>, <div class="newanime-date-area new-count-1 fadeIn" data-animesn="113454" data-date-code="1">
# <div class="anime-content-block">
#
# <div class="date-block">
# <div class="pic-continue">
# <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
# </div>
# <div class="date-block-border"></div>
# </div>
#
# <div class="anime-block">
# <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=37368">
# <div class="anime-pic-block">
#
# <div class="anime-hours-block">
# <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
# <span class="anime-hours">00:30</span>
# </div>
#
# <div class="anime-blocker">
# <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/25/bb06e515f0d5c7c21a0633e45d1p1355.JPG"/>
# </div>
# <div class="line-gradient"></div>
# <div class="anime-detail-info-block">
# <div class="anime-episode">
# <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第8集</p>
# </div>
# <div class="anime-label-block">
#
# </div>
# </div>
# <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(131988, 113454, $(this), "btn-is-active"); return false;'></div>
# </div>
# <div class="anime-name-block">
# <div class="anime-name">
# <p class="">愚蠢天使與惡魔共舞</p>
# <p class="anime-name_for-marquee">愚蠢天使與惡魔共舞</p>
# </div>
# <div class="anime-watch-number">
# <i class="pic-eye-style material-icons">remove_red_eye</i>
# <p>36.5萬</p>
# </div>
# </div>
# </a>
# </div>
# </div>
#
# <span class="anime-date-info anime-date-info-block-arrow">
#
# <svg class="anime-date_svg-is-active" viewBox="0 0 82 28">
# <title>svg_is_active</title>
# <g fill="none" fill-rule="evenodd">
# <g class="anime-date-info_is-active">
# <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
# </g>
# </g>
# </svg>
#
# 02/27 (二)
# </span>
#
# </div>, <div class="newanime-date-area new-count-2 fadeIn" data-animesn="113470" data-date-code="2">
# <div class="anime-content-block">
#
# <div class="date-block">
# <div class="pic-continue">
# <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
# </div>
# <div class="date-block-border"></div>
# </div>
#
# <div class="anime-block">
# <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=37369">
# <div class="anime-pic-block">
#
# <div class="anime-hours-block">
# <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
# <span class="anime-hours">23:00</span>
# </div>
#
# <div class="anime-blocker">
# <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/91/36135992dc6b1024f362b570611p14z5.JPG"/>
# </div>
# <div class="line-gradient"></div>
# <div class="anime-detail-info-block">
# <div class="anime-episode">
# <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第8集</p>
# </div>
# <div class="anime-label-block">
#
# </div>
# </div>
# <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(119792, 113470, $(this), "btn-is-active"); return false;'></div>
# </div>
# <div class="anime-name-block">
# <div class="anime-name">
# <p class="">月光下的異世界之旅 第二季</p>
# <p class="anime-name_for-marquee">月光下的異世界之旅 第二季</p>
# </div>
# <div class="anime-watch-number">
# <i class="pic-eye-style material-icons">remove_red_eye</i>
# <p>97.5萬</p>
# </div>
# </div>
# </a>
# </div>
# </div>
#
# <span class="anime-date-info anime-date-info-block-arrow">
#
# <svg class="anime-date_svg-is-active" viewBox="0 0 82 28">
# <title>svg_is_active</title>
# <g fill="none" fill-rule="evenodd">
# <g class="anime-date-info_is-active">
# <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
# </g>
# </g>
# </svg>
#
# 02/26 (一)
# </span>
#
# <span class="anime-date-info anime-date-info-block-rectangle">
#
# <svg class="anime-date_svg-not-active" viewBox="0 0 82 28">
# <title>svg_not_active</title>
# <g fill="none" fill-rule="evenodd">
# <g class="anime-date-info_not-active">
# <path d="M4,0 L78,0 A4,4 0 0 1 82,4 L82,24 A4,4 0 0 1 78,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
# </g>
# </g>
# </svg>
#
# 02/26 (一)
# </span>
#
# </div>, <div class="newanime-date-area new-count-2 fadeIn" data-animesn="113407" data-date-code="2">
# <div class="anime-content-block">
#
# <div class="date-block">
# <div class="pic-continue">
# <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
# </div>
# <div class="date-block-border"></div>
# </div>
#
# <div class="anime-block">
# <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=37371">
# <div class="anime-pic-block">
#
# <div class="anime-hours-block">
# <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
# <span class="anime-hours">20:00</span>
# </div>
#
# <div class="anime-blocker">
# <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/81/f78eb1beef365c44841d790b3b1p0z55.JPG"/>
# </div>
# <div class="line-gradient"></div>
# <div class="anime-detail-info-block">
# <div class="anime-episode">
# <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第17集</p>
# </div>
# <div class="anime-label-block">
#
# </div>
# </div>
# <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(134389, 113407, $(this), "btn-is-active"); return false;'></div>
# </div>
# <div class="anime-name-block">
# <div class="anime-name">
# <p class="">愛犬訊號</p>
# <p class="anime-name_for-marquee">愛犬訊號</p>
# </div>
# <div class="anime-watch-number">
# <i class="pic-eye-style material-icons">remove_red_eye</i>
# <p>8萬</p>
# </div>
# </div>
# </a>
# </div>
# </div>
#
# <span class="anime-date-info anime-date-info-block-arrow">
#
# <svg class="anime-date_svg-is-active" viewBox="0 0 82 28">
# <title>svg_is_active</title>
# <g fill="none" fill-rule="evenodd">
# <g class="anime-date-info_is-active">
# <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
# </g>
# </g>
# </svg>
#
# 02/26 (一)
# </span>
#
# </div>, <div class="newanime-date-area new-count-2 fadeIn" data-animesn="113464" data-date-code="2">
# <div class="anime-content-block">
#
# <div class="date-block">
# <div class="pic-continue">
# <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
# </div>
# <div class="date-block-border"></div>
# </div>
#
# <div class="anime-block">
# <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=37447">
# <div class="anime-pic-block">
#
# <div class="anime-hours-block">
# <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
# <span class="anime-hours">20:00</span>
# </div>
#
# <div class="anime-blocker">
# <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/84/9ad21f4b5302fc51e8966371321p0z85.JPG"/>
# </div>
# <div class="line-gradient"></div>
# <div class="anime-detail-info-block">
# <div class="anime-episode">
# <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第20集</p>
# </div>
# <div class="anime-label-block">
#
# </div>
# </div>
# <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(131311, 113464, $(this), "btn-is-active"); return false;'></div>
# </div>
# <div class="anime-name-block">
# <div class="anime-name">
# <p class="">HIGH CARD 至高之牌 2</p>
# <p class="anime-name_for-marquee">HIGH CARD 至高之牌 2</p>
# </div>
# <div class="anime-watch-number">
# <i class="pic-eye-style material-icons">remove_red_eye</i>
# <p>6.1萬</p>
# </div>
# </div>
# </a>
# </div>
# </div>
#
# <span class="anime-date-info anime-date-info-block-arrow">
#
# <svg class="anime-date_svg-is-active" viewBox="0 0 82 28">
# <title>svg_is_active</title>
# <g fill="none" fill-rule="evenodd">
# <g class="anime-date-info_is-active">
# <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
# </g>
# </g>
# </svg>
#
# 02/26 (一)
# </span>
#
# </div>, <div class="newanime-date-area new-count-2 fadeIn" data-animesn="113462" data-date-code="2">
# <div class="anime-content-block">
#
# <div class="date-block">
# <div class="pic-continue">
# <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
# </div>
# <div class="date-block-border"></div>
# </div>
#
# <div class="anime-block">
# <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=37342">
# <div class="anime-pic-block">
#
# <div class="anime-hours-block">
# <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
# <span class="anime-hours">03:27</span>
# </div>
#
# <div class="anime-blocker">
# <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/96/298db9196d8b4199b1a68d16c61p0r85.JPG"/>
# </div>
# <div class="line-gradient"></div>
# <div class="anime-detail-info-block">
# <div class="anime-episode">
# <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第8集</p>
# </div>
# <div class="anime-label-block">
#
# </div>
# </div>
# <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(130570, 113462, $(this), "btn-is-active"); return false;'></div>
# </div>
# <div class="anime-name-block">
# <div class="anime-name">
# <p class="">休假的壞人先生</p>
# <p class="anime-name_for-marquee">休假的壞人先生</p>
# </div>
# <div class="anime-watch-number">
# <i class="pic-eye-style material-icons">remove_red_eye</i>
# <p>36.6萬</p>
# </div>
# </div>
# </a>
# </div>
# </div>
#
# <span class="anime-date-info anime-date-info-block-arrow">
#
# <svg class="anime-date_svg-is-active" viewBox="0 0 82 28">
# <title>svg_is_active</title>
# <g fill="none" fill-rule="evenodd">
# <g class="anime-date-info_is-active">
# <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
# </g>
# </g>
# </svg>
#
# 02/26 (一)
# </span>
#
# </div>, <div class="newanime-date-area new-count-3 fadeIn" data-animesn="113441" data-date-code="3">
# <div class="anime-content-block">
#
# <div class="date-block">
# <div class="pic-continue">
# <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
# </div>
# <div class="date-block-border"></div>
# </div>
#
# <div class="anime-block">
# <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=37343">
# <div class="anime-pic-block">
#
# <div class="anime-hours-block">
# <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
# <span class="anime-hours">22:00</span>
# </div>
#
# <div class="anime-blocker">
# <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/16/c9b7fbeed07dd24cc33d4bbd331p0uk5.JPG"/>
# </div>
# <div class="line-gradient"></div>
# <div class="anime-detail-info-block">
# <div class="anime-episode">
# <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第8集</p>
# </div>
# <div class="anime-label-block">
#
# </div>
# </div>
# <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(134939, 113441, $(this), "btn-is-active"); return false;'></div>
# </div>
# <div class="anime-name-block">
# <div class="anime-name">
# <p class="">輪迴七次的惡役千金，在前敵國享受隨心所欲的新婚生活</p>
# <p class="anime-name_for-marquee">輪迴七次的惡役千金，在前敵國享受隨心所欲的新婚生活</p>
# </div>
# <div class="anime-watch-number">
# <i class="pic-eye-style material-icons">remove_red_eye</i>
# <p>84.8萬</p>
# </div>
# </div>
# </a>
# </div>
# </div>
#
# <span class="anime-date-info anime-date-info-block-arrow">
#
# <svg class="anime-date_svg-is-active" viewBox="0 0 82 28">
# <title>svg_is_active</title>
# <g fill="none" fill-rule="evenodd">
# <g class="anime-date-info_is-active">
# <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
# </g>
# </g>
# </svg>
#
# 02/25 (日)
# </span>
#
# <span class="anime-date-info anime-date-info-block-rectangle">
#
# <svg class="anime-date_svg-not-active" viewBox="0 0 82 28">
# <title>svg_not_active</title>
# <g fill="none" fill-rule="evenodd">
# <g class="anime-date-info_not-active">
# <path d="M4,0 L78,0 A4,4 0 0 1 82,4 L82,24 A4,4 0 0 1 78,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
# </g>
# </g>
# </svg>
#
# 02/25 (日)
# </span>
#
# </div>, <div class="newanime-date-area new-count-3 fadeIn" data-animesn="113461" data-date-code="3">
# <div class="anime-content-block">
#
# <div class="date-block">
# <div class="pic-continue">
# <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
# </div>
# <div class="date-block-border"></div>
# </div>
#
# <div class="anime-block">
# <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=37344">
# <div class="anime-pic-block">
#
# <div class="anime-hours-block">
# <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
# <span class="anime-hours">22:00</span>
# </div>
#
# <div class="anime-blocker">
# <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/45/6baff33b43f3499488aef616f41p0pt5.JPG"/>
# </div>
# <div class="line-gradient"></div>
# <div class="anime-detail-info-block">
# <div class="anime-episode">
# <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第7集</p>
# </div>
# <div class="anime-label-block">
#
# </div>
# </div>
# <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(136219, 113461, $(this), "btn-is-active"); return false;'></div>
# </div>
# <div class="anime-name-block">
# <div class="anime-name">
# <p class="">狩火之王 第二季</p>
# <p class="anime-name_for-marquee">狩火之王 第二季</p>
# </div>
# <div class="anime-watch-number">
# <i class="pic-eye-style material-icons">remove_red_eye</i>
# <p>3.3萬</p>
# </div>
# </div>
# </a>
# </div>
# </div>
#
# <span class="anime-date-info anime-date-info-block-arrow">
#
# <svg class="anime-date_svg-is-active" viewBox="0 0 82 28">
# <title>svg_is_active</title>
# <g fill="none" fill-rule="evenodd">
# <g class="anime-date-info_is-active">
# <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
# </g>
# </g>
# </svg>
#
# 02/25 (日)
# </span>
#
# </div>, <div class="newanime-date-area new-count-3 fadeIn" data-animesn="113381" data-date-code="3">
# <div class="anime-content-block">
#
# <div class="date-block">
# <div class="pic-continue">
# <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
# </div>
# <div class="date-block-border"></div>
# </div>
#
# <div class="anime-block">
# <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=37345">
# <div class="anime-pic-block">
#
# <div class="anime-hours-block">
# <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
# <span class="anime-hours">17:30</span>
# </div>
#
# <div class="anime-blocker">
# <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/95/0c1308b652d5930a3d04970fb61p0ln5.JPG"/>
# </div>
# <div class="line-gradient"></div>
# <div class="anime-detail-info-block">
# <div class="anime-episode">
# <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第21集</p>
# </div>
# <div class="anime-label-block">
#
# </div>
# </div>
# <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(131113, 113381, $(this), "btn-is-active"); return false;'></div>
# </div>
# <div class="anime-name-block">
# <div class="anime-name">
# <p class="">隊長小翼 Season2 青少年篇</p>
# <p class="anime-name_for-marquee">隊長小翼 Season2 青少年篇</p>
# </div>
# <div class="anime-watch-number">
# <i class="pic-eye-style material-icons">remove_red_eye</i>
# <p>16.6萬</p>
# </div>
# </div>
# </a>
# </div>
# </div>
#
# <span class="anime-date-info anime-date-info-block-arrow">
#
# <svg class="anime-date_svg-is-active" viewBox="0 0 82 28">
# <title>svg_is_active</title>
# <g fill="none" fill-rule="evenodd">
# <g class="anime-date-info_is-active">
# <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
# </g>
# </g>
# </svg>
#
# 02/25 (日)
# </span>
#
# </div>, <div class="newanime-date-area new-count-3 fadeIn" data-animesn="113380" data-date-code="3">
# <div class="anime-content-block">
#
# <div class="date-block">
# <div class="pic-continue">
# <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
# </div>
# <div class="date-block-border"></div>
# </div>
#
# <div class="anime-block">
# <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=37346">
# <div class="anime-pic-block">
#
# <div class="anime-hours-block">
# <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
# <span class="anime-hours">17:00</span>
# </div>
#
# <div class="anime-blocker">
# <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/17/ef25a749e881c29654de189b321p0ul5.JPG"/>
# </div>
# <div class="line-gradient"></div>
# <div class="anime-detail-info-block">
# <div class="anime-episode">
# <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第20集</p>
# </div>
# <div class="anime-label-block">
#
# </div>
# </div>
# <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(125604, 113380, $(this), "btn-is-active"); return false;'></div>
# </div>
# <div class="anime-name-block">
# <div class="anime-name">
# <p class="">香格里拉・開拓異境～糞作獵手挑戰神作～</p>
# <p class="anime-name_for-marquee">香格里拉・開拓異境～糞作獵手挑戰神作～</p>
# </div>
# <div class="anime-watch-number">
# <i class="pic-eye-style material-icons">remove_red_eye</i>
# <p>486.9萬</p>
# </div>
# </div>
# </a>
# </div>
# </div>
#
# <span class="anime-date-info anime-date-info-block-arrow">
#
# <svg class="anime-date_svg-is-active" viewBox="0 0 82 28">
# <title>svg_is_active</title>
# <g fill="none" fill-rule="evenodd">
# <g class="anime-date-info_is-active">
# <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
# </g>
# </g>
# </svg>
#
# 02/25 (日)
# </span>
#
# </div>, <div class="newanime-date-area new-count-3 fadeIn" data-animesn="113400" data-date-code="3">
# <div class="anime-content-block">
#
# <div class="date-block">
# <div class="pic-continue">
# <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
# </div>
# <div class="date-block-border"></div>
# </div>
#
# <div class="anime-block">
# <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=37347">
# <div class="anime-pic-block">
#
# <div class="anime-hours-block">
# <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
# <span class="anime-hours">11:00</span>
# </div>
#
# <div class="anime-blocker">
# <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/00/01431699f697b87d756cbcc6d81p0ls5.JPG"/>
# </div>
# <div class="line-gradient"></div>
# <div class="anime-detail-info-block">
# <div class="anime-episode">
# <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第18集</p>
# </div>
# <div class="anime-label-block">
#
# </div>
# </div>
# <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(135403, 113400, $(this), "btn-is-active"); return false;'></div>
# </div>
# <div class="anime-name-block">
# <div class="anime-name">
# <p class="">小不點</p>
# <p class="anime-name_for-marquee">小不點</p>
# </div>
# <div class="anime-watch-number">
# <i class="pic-eye-style material-icons">remove_red_eye</i>
# <p>3.1萬</p>
# </div>
# </div>
# </a>
# </div>
# </div>
#
# <span class="anime-date-info anime-date-info-block-arrow">
#
# <svg class="anime-date_svg-is-active" viewBox="0 0 82 28">
# <title>svg_is_active</title>
# <g fill="none" fill-rule="evenodd">
# <g class="anime-date-info_is-active">
# <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
# </g>
# </g>
# </svg>
#
# 02/25 (日)
# </span>
#
# </div>, <div class="newanime-date-area new-count-3 fadeIn" data-animesn="113460" data-date-code="3">
# <div class="anime-content-block">
#
# <div class="date-block">
# <div class="pic-continue">
# <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
# </div>
# <div class="date-block-border"></div>
# </div>
#
# <div class="anime-block">
# <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=37348">
# <div class="anime-pic-block">
#
# <div class="anime-hours-block">
# <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
# <span class="anime-hours">02:00</span>
# </div>
#
# <div class="anime-blocker">
# <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/96/8bc8988c582cc3de8ef5d4eaeb1p0lo5.JPG"/>
# </div>
# <div class="line-gradient"></div>
# <div class="anime-detail-info-block">
# <div class="anime-episode">
# <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第20集</p>
# </div>
# <div class="anime-label-block">
#
# </div>
# </div>
# <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(
JPG"/>
# </div>
# <div class="line-gradient"></div>
# <div class="anime-detail-info-block">
# <div class="anime-episode">
# <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第7集</p>
# </div>
# <div class="anime-label-block">
#
# </div>
# </div>
# <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(130648, 113465, $(this), "btn-is-active"); return false;'></div>
# </div>
# <div class="anime-name-block">
# <div class="anime-name">
# <p class="">女王的手術刀</p>
# <p class="anime-name_for-marquee">女王的手術刀</p>
# </div>
# <div class="anime-watch-number">
# <i class="pic-eye-style material-icons">remove_red_eye</i>
# <p>28.7萬</p>
# </div>
# </div>
# </a>
# </div>
# </div>
#
# <span class="anime-date-info anime-date-info-block-arrow">
#
# <svg class="anime-date_svg-is-active" viewBox="0 0 82 28">
# <title>svg_is_active</title>
# <g fill="none" fill-rule="evenodd">
# <g class="anime-date-info_is-active">
# <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
# </g>
# </g>
# </svg>
#
# 02/21 (三)
# </span>
#
# </div>, <div class="newanime-date-area new-count-7 newanime-content-hide fadeIn" data-animesn="113444" data-date-code="7">
# <div class="anime-content-block">
#
# <div class="date-block">
# <div class="pic-continue">
# <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
# </div>
# <div class="date-block-border"></div>
# </div>
#
# <div class="anime-block">
# <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=37331">
# <div class="anime-pic-block">
#
# <div class="anime-hours-block">
# <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
# <span class="anime-hours">20:30</span>
# </div>
#
# <div class="anime-blocker">
# <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/31/b700bff0ec1dfd400bc6ef117a1oz0b5.JPG"/>
# </div>
# <div class="line-gradient"></div>
# <div class="anime-detail-info-block">
# <div class="anime-episode">
# <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第8集</p>
# </div>
# <div class="anime-label-block">
#
# </div>
# </div>
# <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(122302, 113444, $(this), "btn-is-active"); return false;'></div>
# </div>
# <div class="anime-name-block">
# <div class="anime-name">
# <p class="">弱角友崎同學 2nd STAGE</p>
# <p class="anime-name_for-marquee">弱角友崎同學 2nd STAGE</p>
# </div>
# <div class="anime-watch-number">
# <i class="pic-eye-style material-icons">remove_red_eye</i>
# <p>15.9萬</p>
# </div>
# </div>
# </a>
# </div>
# </div>
#
# <span class="anime-date-info anime-date-info-block-arrow">
#
# <svg class="anime-date_svg-is-active" viewBox="0 0 82 28">
# <title>svg_is_active</title>
# <g fill="none" fill-rule="evenodd">
# <g class="anime-date-info_is-active">
# <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
# </g>
# </g>
# </svg>
#
# 02/21 (三)
# </span>
#
# </div>, <div class="newanime-date-area new-count-8 newanime-content-hide fadeIn" data-animesn="113467" data-date-code="8">
# <div class="anime-content-block">
#
# <div class="date-block">
# <div class="pic-continue">
# <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
# </div>
# <div class="date-block-border"></div>
# </div>
#
# <div class="anime-block">
# <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=37270">
# <div class="anime-pic-block">
#
# <div class="anime-hours-block">
# <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
# <span class="anime-hours">23:30</span>
# </div>
#
# <div class="anime-blocker">
# <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/07/6bc3d7b82a09462f1c8ffc5b671oywv5.JPG"/>
# </div>
# <div class="line-gradient"></div>
# <div class="anime-detail-info-block">
# <div class="anime-episode">
# <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第7集</p>
# </div>
# <div class="anime-label-block">
#
# </div>
# </div>
# <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(131194, 113467, $(this), "btn-is-active"); return false;'></div>
# </div>
# <div class="anime-name-block">
# <div class="anime-name">
# <p class="">反派千金等級 99～我是隱藏頭目但不是魔王～</p>
# <p class="anime-name_for-marquee">反派千金等級 99～我是隱藏頭目但不是魔王～</p>
# </div>
# <div class="anime-watch-number">
# <i class="pic-eye-style material-icons">remove_red_eye</i>
# <p>129.4萬</p>
# </div>
# </div>
# </a>
# </div>
# </div>
#
# <span class="anime-date-info anime-date-info-block-arrow">
#
# <svg class="anime-date_svg-is-active" viewBox="0 0 82 28">
# <title>svg_is_active</title>
# <g fill="none" fill-rule="evenodd">
# <g class="anime-date-info_is-active">
# <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
# </g>
# </g>
# </svg>
#
# 02/20 (二)
# </span>
#
# <span class="anime-date-info anime-date-info-block-rectangle">
#
# <svg class="anime-date_svg-not-active" viewBox="0 0 82 28">
# <title>svg_not_active</title>
# <g fill="none" fill-rule="evenodd">
# <g class="anime-date-info_not-active">
# <path d="M4,0 L78,0 A4,4 0 0 1 82,4 L82,24 A4,4 0 0 1 78,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
# </g>
# </g>
# </svg>
#
# 02/20 (二)
# </span>
#
# </div>, <div class="newanime-date-area new-count-9 newanime-content-hide fadeIn" data-animesn="113476" data-date-code="9">
# <div class="anime-content-block">
#
# <div class="date-block">
# <div class="pic-continue">
# <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
# </div>
# <div class="date-block-border"></div>
# </div>
#
# <div class="anime-block">
# <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=37231">
# <div class="anime-pic-block">
#
# <div class="anime-hours-block">
# <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
# <span class="anime-hours">18:00</span>
# </div>
#
# <div class="anime-blocker">
# <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/59/165418224319ba470c9dae183f1oy0z5.JPG"/>
# </div>
# <div class="line-gradient"></div>
# <div class="anime-detail-info-block">
# <div class="anime-episode">
# <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第6集</p>
# </div>
# <div class="anime-label-block">
#
# </div>
# </div>
# <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(136407, 113476, $(this), "btn-is-active"); return false;'></div>
# </div>
# <div class="anime-name-block">
# <div class="anime-name">
# <p class="">卡片戰鬥!! 先導者 Divinez</p>
# <p class="anime-name_for-marquee">卡片戰鬥!! 先導者 Divinez</p>
# </div>
# <div class="anime-watch-number">
# <i class="pic-eye-style material-icons">remove_red_eye</i>
# <p>1.1萬</p>
# </div>
# </div>
# </a>
# </div>
# </div>
#
# <span class="anime-date-info anime-date-info-block-arrow">
#
# <svg class="anime-date_svg-is-active" viewBox="0 0 82 28">
# <title>svg_is_active</title>
# <g fill="none" fill-rule="evenodd">
# <g class="anime-date-info_is-active">
# <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
# </g>
# </g>
# </svg>
#
# 02/17 (六)
# </span>
#
# <span class="anime-date-info anime-date-info-block-rectangle">
#
# <svg class="anime-date_svg-not-active" viewBox="0 0 82 28">
# <title>svg_not_active</title>
# <g fill="none" fill-rule="evenodd">
# <g class="anime-date-info_not-active">
# <path d="M4,0 L78,0 A4,4 0 0 1 82,4 L82,24 A4,4 0 0 1 78,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
# </g>
# </g>
# </svg>
#
# 02/17 (六)
# </span>
#
# </div>, <div class="newanime-date-area new-count-10 newanime-content-hide fadeIn" data-animesn="113469" data-date-code="10">
# <div class="anime-content-block">
#
# <div class="date-block">
# <div class="pic-continue">
# <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
# </div>
# <div class="date-block-border"></div>
# </div>
#
# <div class="anime-block">
# <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=37165">
# <div class="anime-pic-block">
#
# <div class="anime-hours-block">
# <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
# <span class="anime-hours">01:28</span>
# </div>
#
# <div class="anime-blocker">
# <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/87/7bc2c4e958c4b8203669dde19a1oxib5.JPG"/>
# </div>
# <div class="line-gradient"></div>
# <div class="anime-detail-info-block">
# <div class="anime-episode">
# <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第6集</p>
# </div>
# <div class="anime-label-block">
#
# </div>
# </div>
# <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(126540, 113469, $(this), "btn-is-active"); return false;'></div>
# </div>
# <div class="anime-name-block">
# <div class="anime-name">
# <p class="">魔女與野獸</p>
# <p class="anime-name_for-marquee">魔女與野獸</p>
# </div>
# <div class="anime-watch-number">
# <i class="pic-eye-style material-icons">remove_red_eye</i>
# <p>24萬</p>
# </div>
# </div>
# </a>
# </div>
# </div>
#
# <span class="anime-date-info anime-date-info-block-arrow">
#
# <svg class="anime-date_svg-is-active" viewBox="0 0 82 28">
# <title>svg_is_active</title>
# <g fill="none" fill-rule="evenodd">
# <g class="anime-date-info_is-active">
# <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
# </g>
# </g>
# </svg>
#
# 02/16 (五)
# </span>
#
# <span class="anime-date-info anime-date-info-block-rectangle">
#
# <svg class="anime-date_svg-not-active" viewBox="0 0 82 28">
# <title>svg_not_active</title>
# <g fill="none" fill-rule="evenodd">
# <g class="anime-date-info_not-active">
# <path d="M4,0 L78,0 A4,4 0 0 1 82,4 L82,24 A4,4 0 0 1 78,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
# </g>
# </g>
# </svg>
#
# 02/16 (五)
# </span>
#
# </div>, <div class="newanime-date-area new-count-11 newanime-content-hide fadeIn" data-animesn="113463" data-date-code="11">
# <div class="anime-content-block">
#
# <div class="date-block">
# <div class="pic-continue">
# <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
# </div>
# <div class="date-block-border"></div>
# </div>
#
# <div class="anime-block">
# <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=36968">
# <div class="anime-pic-block">
#
# <div class="anime-hours-block">
# <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
# <span class="anime-hours">23:00</span>
# </div>
#
# <div class="anime-blocker">
# <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/01/cc1ae98f6f5acb5a6b817b73dd1onc15.JPG"/>
# </div>
# <div class="line-gradient"></div>
# <div class="anime-detail-info-block">
# <div class="anime-episode">
# <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第1集</p>
# </div>
# <div class="anime-label-block">
#
# </div>
# </div>
# <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(134326, 113463, $(this), "btn-is-active"); return false;'></div>
# </div>
# <div class="anime-name-block">
# <div class="anime-name">
# <p class="">MONSTERS 一百三情飛龍侍極</p>
# <p class="anime-name_for-marquee">MONSTERS 一百三情飛龍侍極</p>
# </div>
# <div class="anime-watch-number">
# <i class="pic-eye-style material-icons">remove_red_eye</i>
# <p>4.3萬</p>
# </div>
# </div>
# </a>
# </div>
# </div>
#
# <span class="anime-date-info anime-date-info-block-arrow">
#
# <svg class="anime-date_svg-is-active" viewBox="0 0 82 28">
# <title>svg_is_active</title>
# <g fill="none" fill-rule="evenodd">
# <g class="anime-date-info_is-active">
# <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
# </g>
# </g>
# </svg>
#
# 01/21 (日)
# </span>
#
# <span class="anime-date-info anime-date-info-block-rectangle">
#
# <svg class="anime-date_svg-not-active" viewBox="0 0 82 28">
# <title>svg_not_active</title>
# <g fill="none" fill-rule="evenodd">
# <g class="anime-date-info_not-active">
# <path d="M4,0 L78,0 A4,4 0 0 1 82,4 L82,24 A4,4 0 0 1 78,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
# </g>
# </g>
# </svg>
#
# 01/21 (日)
# </span>
#
# </div>, <div class="premium-block newanime-date-area newanime-content-hide fadeIn">
# <div class="premium-info">
# <div class="premium-info--count">
# <div class="premium-info__title">
# <span class="heading">付費比例</span>
# <span class="number">13.73</span>
# </div>
# </div>
# <div class="premium-info--intro">
# <p>付費比例是以目前付費會員數量與30日內不重複之觀眾總數計算，本數值每日更新一次。</p>
# </div>
# </div>
# </div>]

# %%
# 印出幾組動畫元素
print(len(anime_items))
# Out:
# 47

# %% [markdown]
# ## 3. 抓取動畫名稱、觀看人數、動畫集數、觀看連結

# %% [markdown]
# ### 3-1. 動畫名稱

# %%
# 取得第一組動漫名稱元素
anime_name = newanime_item.select_one('.anime-name > p')

# %%
anime_name
# Out:
# <p class="">公主殿下，「拷問」的時間到了</p>

# %%
# 取得元素裡的文字
anime_name = newanime_item.select_one('.anime-name > p').text
anime_name
# Out:
# '公主殿下，「拷問」的時間到了'

# %%
# 使用 strip() 將字串的前後空格和換行去除
anime_name = anime_name.strip()
anime_name
# Out:
# '公主殿下，「拷問」的時間到了'

# %% [markdown]
# ### 3-2. 觀看人數

# %%
# 取得第一組動漫觀看人數元素
anime_watch_number = newanime_item.select_one('.anime-watch-number > p')

# %%
anime_watch_number
# Out:
# <p>30萬</p>

# %%
# 取得元素裡的字
anime_watch_number = newanime_item.select_one('.anime-watch-number > p').text.strip()
anime_watch_number
# Out:
# '30萬'

# %% [markdown]
# ### 3-3. 動畫集數

# %%
anime_episode = newanime_item.select_one('.anime-episode > p')

# %%
anime_episode
# Out:
# <p>第8集</p>

# %%
anime_watch_number = newanime_item.select_one('.anime-episode > p').text.strip()
anime_watch_number
# Out:
# '第8集'

# %% [markdown]
# ### 3-4. 觀看連結

# %% [markdown]
# "觀看連結" 稍微特別一點，連結並不是以文字形式被包在元素之間，
# 而是在元素裡的 href 屬性，這時要透過 get('href') 方法來取得。

# %%
anime_href = newanime_item.select_one('a.anime-card-block').get('href')
print(os.path.join(url, anime_href))
# Out:
# https://ani.gamer.com.tw/animeVideo.php?sn=37367

# %% [markdown]
# ## 4. 函式實現

# %%
def read_headers_ua(headers_path: str) -> dict:
    """
    讀取 Headers 內的 "User-Agent"。

    :param headers_path: Headers 的路徑
    :type headers_path: str
    :return: User-Agent
    :rtype: str
    """
    with open(headers_path) as f:
        lines = f.readlines()
        headers_dict = {'User-Agent': lines[0].strip()}
        return headers_dict

# %%
def show_new_anime(url: str, ua: dict) -> None:
    r = requests.get(url, headers=ua)
    if r.status_code == 200:
        print(f'請求成功: {r.status_code}')

        soup = BeautifulSoup(r.text, 'html5lib')

        new_anime_item = soup.select_one('.timeline-ver > .newanime-block')

        anime_items = new_anime_item.select('.newanime-date-area')

        for anime_item in anime_items:
            anime_name = anime_item.select_one('.anime-name > p')
            print(f'Name: {anime_name}')

            anime_watch_number = anime_item.select_one('.anime-watch-number > p')
            print(f'Watch number: {anime_watch_number}')

            anime_episode = anime_item.select_one('.anime-episode > p')
            print(f'Episode: {anime_episode}')

            anime_href = anime_item.select_one('a.anime-card-block').get('href')
            print(f'Href: {os.path.join(url, anime_href)}')
    else:
        print(f'請求失敗: {r.status_code}')

# %%
url = 'https://ani.gamer.com.tw/'
headers = os.path.join(os.getcwd(), 'header_UA.txt')
user_agent = read_headers_ua(headers)

# %%
# show_new_anime(url, ua=user_agent)

# %% [markdown]
# 執行後會發現會出現錯誤，原來是最後這個"付費比例"區塊搞的鬼，它也同樣有 newanime-date-area 這個 class，
# 一樣會被抓出來，但它沒有動畫名稱，所以才會造成後續在取得文字時發生錯誤。

# %% [markdown]
# 正確的函式 :

# %%
def show_new_anime(url: str, ua: dict) -> None:
    r = requests.get(url, headers=ua)
    if r.status_code == 200:
        print(f'請求成功: {r.status_code}')

        soup = BeautifulSoup(r.text, 'html5lib')
        new_anime_item = soup.select_one('.timeline-ver > .newanime-block')
        anime_items = new_anime_item.select('.newanime-date-area:not(.premium-block)')

        for anime_item in anime_items:
            anime_name = anime_item.select_one('.anime-name > p').text.strip()
            print(f'Name: {anime_name}')
            anime_watch_number = anime_item.select_one('.anime-watch-number > p').text.strip()
            print(f'Watch number: {anime_watch_number}  人')
            anime_episode = anime_item.select_one('.anime-episode > p').text.strip()
            print(f'Episode: {anime_episode}')
            anime_href = anime_item.select_one('a.anime-card-block').get('href')
            print(f'url: {os.path.join(url, anime_href)}')
            print('------------------------')
    else:
        print(f'請求失敗: {r.status_code}')

# %%
show_new_anime(url, ua=user_agent)
# Out:
# 請求成功: 200
# Name: 公主殿下，「拷問」的時間到了
# Watch number: 30萬  人
# Episode: 第8集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37367
# ------------------------
# Name: 愚蠢天使與惡魔共舞
# Watch number: 36.5萬  人
# Episode: 第8集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37368
# ------------------------
# Name: 月光下的異世界之旅 第二季
# Watch number: 97.5萬  人
# Episode: 第8集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37369
# ------------------------
# Name: 愛犬訊號
# Watch number: 8萬  人
# Episode: 第17集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37371
# ------------------------
# Name: HIGH CARD 至高之牌 2
# Watch number: 6.1萬  人
# Episode: 第20集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37447
# ------------------------
# Name: 休假的壞人先生
# Watch number: 36.6萬  人
# Episode: 第8集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37342
# ------------------------
# Name: 輪迴七次的惡役千金，在前敵國享受隨心所欲的新婚生活
# Watch number: 84.8萬  人
# Episode: 第8集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37343
# ------------------------
# Name: 狩火之王 第二季
# Watch number: 3.3萬  人
# Episode: 第7集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37344
# ------------------------
# Name: 隊長小翼 Season2 青少年篇
# Watch number: 16.6萬  人
# Episode: 第21集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37345
# ------------------------
# Name: 香格里拉・開拓異境～糞作獵手挑戰神作～
# Watch number: 486.9萬  人
# Episode: 第20集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37346
# ------------------------
# Name: 小不點
# Watch number: 3.1萬  人
# Episode: 第18集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37347
# ------------------------
# Name: 我內心的糟糕念頭 第二季
# Watch number: 112.5萬  人
# Episode: 第20集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37348
# ------------------------
# Name: 最強肉盾的迷宮攻略～擁有稀少技能體力 9999 的肉盾，被勇者隊伍辭退了～
# Watch number: 70.3萬  人
# Episode: 第8集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37349
# ------------------------
# Name: 青之驅魔師 島根啟明結社篇
# Watch number: 30萬  人
# Episode: 第8集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37350
# ------------------------
# Name: 我獨自升級
# Watch number: 217.1萬  人
# Episode: 第7.5集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37351
# ------------------------
# Name: 狩龍人拉格納
# Watch number: 170.3萬  人
# Episode: 第19集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37352
# ------------------------
# Name: 肌肉魔法使-MASHLE- 神覺者候補選拔試驗篇
# Watch number: 136.1萬  人
# Episode: 第19集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37227
# ------------------------
# Name: 指尖相觸，戀戀不捨
# Watch number: 31.1萬  人
# Episode: 第8集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37354
# ------------------------
# Name: 婚戒物語
# Watch number: 35.1萬  人
# Episode: 第8集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37355
# ------------------------
# Name: 烈焰先鋒 救國的橘衣消防員
# Watch number: 20.4萬  人
# Episode: 第19集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37356
# ------------------------
# Name: 碰之道
# Watch number: 17.4萬  人
# Episode: 第8集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37358
# ------------------------
# Name: 不死不運
# Watch number: 280.1萬  人
# Episode: 第20集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37359
# ------------------------
# Name: 小酒館 Basue
# Watch number: 7.6萬  人
# Episode: 第7集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37360
# ------------------------
# Name: 百千家的妖怪王子
# Watch number: 10.8萬  人
# Episode: 第8集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37361
# ------------------------
# Name: 治癒魔法的錯誤使用法
# Watch number: 108.9萬  人
# Episode: 第8集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37363
# ------------------------
# Name: 葬送的芙莉蓮
# Watch number: 861.6萬  人
# Episode: 第24集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37362
# ------------------------
# Name: 最弱魔物使開始了撿垃圾之旅。
# Watch number: 41.2萬  人
# Episode: 第7集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37364
# ------------------------
# Name: 非自願的不死冒險者
# Watch number: 79.4萬  人
# Episode: 第8集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37365
# ------------------------
# Name: 佐佐木與文鳥小嗶
# Watch number: 61.3萬  人
# Episode: 第8集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37366
# ------------------------
# Name: 她來自煩星 第二季
# Watch number: 10萬  人
# Episode: 第30集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37335
# ------------------------
# Name: 秒殺外掛太強了，異世界的傢伙們根本就不是對手。
# Watch number: 100.1萬  人
# Episode: 第8集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37337
# ------------------------
# Name: 月刊妄想科學
# Watch number: 2.8萬  人
# Episode: 第7集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37338
# ------------------------
# Name: 名湯「異世界溫泉」開拓記～30 多歲溫泉狂熱者，轉生到悠閒的溫泉天國～
# Watch number: 38.5萬  人
# Episode: 第7集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37339
# ------------------------
# Name: 勇氣爆發 BANG BRAVERN
# Watch number: 73.9萬  人
# Episode: 第7集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37340
# ------------------------
# Name: 魔都精兵的奴隸
# Watch number: 89萬  人
# Episode: 第8集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37341
# ------------------------
# Name: 如果 30 歲還是處男，似乎就能成為魔法師
# Watch number: 32.3萬  人
# Episode: 第7集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37326
# ------------------------
# Name: 金屬口紅
# Watch number: 14.3萬  人
# Episode: 第7集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37325
# ------------------------
# Name: 夢想成為魔法少女
# Watch number: 72.6萬  人
# Episode: 第8集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37327
# ------------------------
# Name: 戰國妖狐
# Watch number: 14.8萬  人
# Episode: 第7集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37328
# ------------------------
# Name: 歡迎來到實力至上主義的教室 第三季
# Watch number: 103.7萬  人
# Episode: 第8集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37329
# ------------------------
# Name: 女王的手術刀
# Watch number: 28.7萬  人
# Episode: 第7集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37330
# ------------------------
# Name: 弱角友崎同學 2nd STAGE
# Watch number: 15.9萬  人
# Episode: 第8集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37331
# ------------------------
# Name: 反派千金等級 99～我是隱藏頭目但不是魔王～
# Watch number: 129.4萬  人
# Episode: 第7集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37270
# ------------------------
# Name: 卡片戰鬥!! 先導者 Divinez
# Watch number: 1.1萬  人
# Episode: 第6集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37231
# ------------------------
# Name: 魔女與野獸
# Watch number: 24萬  人
# Episode: 第6集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37165
# ------------------------
# Name: MONSTERS 一百三情飛龍侍極
# Watch number: 4.3萬  人
# Episode: 第1集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=36968
# ------------------------

# %% [markdown]
# ## 5. 增加功能 : 動畫的圖片網址、切換到週期表的畫面

# %%
def show_new_anime(url: str, ua: dict) -> None:
    r = requests.get(url, headers=ua)
    if r.status_code == 200:
        print(f'請求成功: {r.status_code}')

        soup = BeautifulSoup(r.text, 'html5lib')
        new_anime_item = soup.select_one('.timeline-ver > .newanime-block')
        anime_items = new_anime_item.select('.newanime-date-area:not(.premium-block)')

        for anime_item in anime_items:
            anime_name = anime_item.select_one('.anime-name > p').text.strip()
            print(f'Name: {anime_name}')  # 動畫名字
            anime_watch_number = anime_item.select_one('.anime-watch-number > p').text.strip()
            print(f'Watch number: {anime_watch_number}  人')  # 觀看人數
            anime_episode = anime_item.select_one('.anime-episode > p').text.strip()
            print(f'Episode: {anime_episode}')  # 集數
            anime_href = anime_item.select_one('a.anime-card-block').get('href')
            print(f'url: {os.path.join(url, anime_href)}')  # 影片網址
            anime_img_url = anime_item.select_one('img.lazyload').get('data-src')
            print(f'img url: {anime_img_url}')  # 動畫縮圖網址
            anime_date = str(anime_item.select_one('.anime-date-info').contents[-1]).strip()
            print(f'Date: {anime_date}')  # 動畫播放日期
            anime_time = anime_item.select_one('.anime-hours').text.strip()
            print(anime_time)  # 動畫播放時間
            print('------------------------')
    else:
        print(f'請求失敗: {r.status_code}')

# %%
show_new_anime(url, ua=user_agent)
# Out:
# 請求成功: 200
# Name: 公主殿下，「拷問」的時間到了
# Watch number: 30萬  人
# Episode: 第8集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37367
# img url: https://p2.bahamut.com.tw/B/2KU/32/29526e237be2842d21286a4bc51p13c5.JPG
# Date: 02/27 (二)
# 00:30
# ------------------------
# Name: 愚蠢天使與惡魔共舞
# Watch number: 36.5萬  人
# Episode: 第8集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37368
# img url: https://p2.bahamut.com.tw/B/2KU/25/bb06e515f0d5c7c21a0633e45d1p1355.JPG
# Date: 02/27 (二)
# 00:30
# ------------------------
# Name: 月光下的異世界之旅 第二季
# Watch number: 97.5萬  人
# Episode: 第8集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37369
# img url: https://p2.bahamut.com.tw/B/2KU/91/36135992dc6b1024f362b570611p14z5.JPG
# Date: 02/26 (一)
# 23:00
# ------------------------
# Name: 愛犬訊號
# Watch number: 8萬  人
# Episode: 第17集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37371
# img url: https://p2.bahamut.com.tw/B/2KU/81/f78eb1beef365c44841d790b3b1p0z55.JPG
# Date: 02/26 (一)
# 20:00
# ------------------------
# Name: HIGH CARD 至高之牌 2
# Watch number: 6.1萬  人
# Episode: 第20集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37447
# img url: https://p2.bahamut.com.tw/B/2KU/84/9ad21f4b5302fc51e8966371321p0z85.JPG
# Date: 02/26 (一)
# 20:00
# ------------------------
# Name: 休假的壞人先生
# Watch number: 36.6萬  人
# Episode: 第8集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37342
# img url: https://p2.bahamut.com.tw/B/2KU/96/298db9196d8b4199b1a68d16c61p0r85.JPG
# Date: 02/26 (一)
# 03:27
# ------------------------
# Name: 輪迴七次的惡役千金，在前敵國享受隨心所欲的新婚生活
# Watch number: 84.8萬  人
# Episode: 第8集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37343
# img url: https://p2.bahamut.com.tw/B/2KU/16/c9b7fbeed07dd24cc33d4bbd331p0uk5.JPG
# Date: 02/25 (日)
# 22:00
# ------------------------
# Name: 狩火之王 第二季
# Watch number: 3.3萬  人
# Episode: 第7集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=37344
# img url: https://p2.bahamut.com.tw/B/2KU/45/6baff33b43f3499488aef616f41p0pt5.JPG
# Date: 02/25 (日)
# 22:00
# ------------------------
# Name: 隊長小翼 Season2 青少年篇
# Watch number: 16.6萬  人
# Episode: 第21集
# url: https://ani.gamer.com.tw/animeVideo.php?sn=